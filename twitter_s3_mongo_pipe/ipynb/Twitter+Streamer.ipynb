# %% [markdown]
# Use `pip` to install `twitter`.

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /opt/conda/lib/python3.6/site-packages
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# Import `TwitterStream` and `OAuth` from `twitter`.

# %%
from twitter import TwitterStream,OAuth

# %% [markdown]
# ### `oauth`

# %% [markdown]
# Create a new object called `oauth` using `OAuth`.
#
#     OAuth(token, token_secret, consumer_key, consumer_secret)

# %%
token ='1019793971629789184-yi7r3HwZFPQRcFPiFy1TGCDF7d2II0'
token_secret ='2U0z3Srf9yfChASncmQj4lqpxssjftxdYkuKnCkkWIQ08'
consumer_key ='lJqaPrC9JVHW70jauorbOJIKl'
consumer_secret ='LSG2wNMQHUiho9DmK7EDvzLObXVAG2XatXQVAQw38IlqwxIGDo'

# %%
oauth=OAuth(token, token_secret, consumer_key, consumer_secret)
oauth

# %% [markdown]
# Create a new object called `twitter_stream` using `TwitterStream`.
#
# Use the argument `auth=oauth` referencing the `oauth` object you just made.

# %% [markdown]
# ### `twitter_stream`

# %%
twitter_stream=TwitterStream(auth=oauth)

# %% [markdown]
# ### `bounding_box`

# %% [markdown]
# Create a string called `bounding_box`. The string should contain the geo-coordinates of a bounding box separated by commas. These values are for Santa Monica:
#
#     -118.5137323688,34.0001996344,-118.4702449172,34.0331651696
#
# You can make your own here: https://boundingbox.klokantech.com. Be sure to specify CSV RAW to get the values in this format.
#
# ![](https://www.evernote.com/l/AAH3H9KGE6hD9JpPJPFncw09exRyoYSid5IB/image.png)

# %%
bounding_box='-117.8687519,33.5993914,-117.6780258,33.7736521'

# %% [markdown]
# ### `tweet_iterator`
#
# Create an object called `tweet_iterator`.
#
# 1. Use `twitter_stream`.
# 1. Apply `.statuses` to grab statuses.
# 1. Apply a `.filter()` with the argument `locations=bounding_box`.

# %%
tweet_iterator=(twitter_stream.statuses.filter(locations=bounding_box))

# %% [markdown]
# Get the next value from the `tweet_iterator` and store it as the variable `this_tweet`.

# %%
next(tweet_iterator)
# Out:
# {'created_at': 'Tue Jul 24 00:48:14 +0000 2018',
#  'id': 1021557636376883200,
#  'id_str': '1021557636376883200',
#  'text': 'We also have some amazing student speakers and performers from that will be showcased at the Equity in Education co… https://t.co/Srn7WifY90',
#  'display_text_range': [0, 140],
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': True,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 890969515336642562,
#   'id_str': '890969515336642562',
#   'name': 'Laurel Kirchhoff',
#   'screen_name': 'HistoryKirchh',
#   'location': 'California, USA',
#   'url': None,
#   'description': 'CNUSD Educator 🍎 and Soccer Mom ⚽️ National History Day is my jam! 📜(All Tweets/Opinions are my own)',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 136,
#   'friends_count': 457,
#   'listed_count': 3,
#   'favourites_count': 2433,
#   'statuses_count': 192,
#   'created_at': 'Fri Jul 28 16:17:40 +0000 2017',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': '',
#   'profile_background_image_url_https': '',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1020861352552804354/7HGIHAYu_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1020861352552804354/7HGIHAYu_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/890969515336642562/1501259143',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': {'id': 'fbd6d2f5a4e4a15e',
#   'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#   'place_type': 'admin',
#   'name': 'California',
#   'full_name': 'California, USA',
#   'country_code': 'US',
#   'country': 'United States',
#   'bounding_box': {'type': 'Polygon',
#    'coordinates': [[[-124.482003, 32.528832],
#      [-124.482003, 42.009519],
#      [-114.131212, 42.009519],
#      [-114.131212, 32.528832]]]},
#   'attributes': {}},
#  'contributors': None,
#  'quoted_status_id': 1021445383233286145,
#  'quoted_status_id_str': '1021445383233286145',
#  'quoted_status': {'created_at': 'Mon Jul 23 17:22:11 +0000 2018',
#   'id': 1021445383233286145,
#   'id_str': '1021445383233286145',
#   'text': 'There is still time to register for our 2nd Annual Equity in Education conference taking place August 2nd &amp; 3rd! Le… https://t.co/VCIPqfmq3Z',
#   'display_text_range': [0, 140],
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 64570444,
#    'id_str': '64570444',
#    'name': 'Corona-Norco USD',
#    'screen_name': 'CNUSD',
#    'location': 'Corona | Norco | Eastvale',
#    'url': 'http://www.cnusd.k12.ca.us/',
#    'description': 'Official Twitter account for CNUSD. Serving over 54,000 students, we are the largest school district in Riverside County & the 9th largest district in CA.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': True,
#    'followers_count': 3698,
#    'friends_count': 303,
#    'listed_count': 57,
#    'favourites_count': 957,
#    'statuses_count': 5414,
#    'created_at': 'Tue Aug 11 00:37:07 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/644230805405863936/KRtmkXQI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/644230805405863936/KRtmkXQI_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/64570444/1490135367',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': "There is still time to register for our 2nd Annual Equity in Education conference taking place August 2nd &amp; 3rd! Learn more about a few of the guest speakers! You don't want to miss it! To register visit: https://t.co/vBM7RKjOEj . #CNUSDEquity18 #CNUSDFutureReady https://t.co/b3IWtfhSQo",
#    'display_text_range': [0, 267],
#    'entities': {'hashtags': [{'text': 'CNUSDEquity18', 'indices': [235, 249]},
#      {'text': 'CNUSDFutureReady', 'indices': [250, 267]}],
#     'urls': [{'url': 'https://t.co/vBM7RKjOEj',
#       'expanded_url': 'http://www.cnusd.k12.ca.us/edchat',
#       'display_url': 'cnusd.k12.ca.us/edchat',
#       'indices': [209, 232]}],
#     'user_mentions': [],
#     'symbols': [],
#     'media': [{'id': 1021445262403809280,
#       'id_str': '1021445262403809280',
#       'indices': [268, 291],
#       'media_url': 'http://pbs.twimg.com/media/DiznDecVsAAJuFd.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DiznDecVsAAJuFd.jpg',
#       'url': 'https://t.co/b3IWtfhSQo',
#       'display_url': 'pic.twitter.com/b3IWtfhSQo',
#       'expanded_url': 'https://twitter.com/CNUSD/status/1021445383233286145/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1583, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 927, 'h': 1200, 'resize': 'fit'}}},
#      {'id': 1021445333807607809,
#       'id_str': '1021445333807607809',
#       'indices': [268, 291],
#       'media_url': 'http://pbs.twimg.com/media/DiznHocVMAE1Yr3.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DiznHocVMAE1Yr3.jpg',
#       'url': 'https://t.co/b3IWtfhSQo',
#       'display_url': 'pic.twitter.com/b3IWtfhSQo',
#       'expanded_url': 'https://twitter.com/CNUSD/status/1021445383233286145/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 927, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1583, 'h': 2048, 'resize': 'fit'}}},
#      {'id': 1021445337788006400,
#       'id_str': '1021445337788006400',
#       'indices': [268, 291],
#       'media_url': 'http://pbs.twimg.com/media/DiznH3RVQAAwmIX.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DiznH3RVQAAwmIX.jpg',
#       'url': 'https://t.co/b3IWtfhSQo',
#       'display_url': 'pic.twitter.com/b3IWtfhSQo',
#       'expanded_url': 'https://twitter.com/CNUSD/status/1021445383233286145/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1583, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 927, 'h': 1200, 'resize': 'fit'}}},
#      {'id': 1021445334675873792,
#       'id_str': '1021445334675873792',
#       'indices': [268, 291],
#       'media_url': 'http://pbs.twimg.com/media/DiznHrrV4AAyYhf.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DiznHrrV4AAyYhf.jpg',
#       'url': 'https://t.co/b3IWtfhSQo',
#       'display_url': 'pic.twitter.com/b3IWtfhSQo',
#       'expanded_url': 'https://twitter.com/CNUSD/status/1021445383233286145/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 927, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1583, 'h': 2048, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1021445262403809280,
#       'id_str': '1021445262403809280',
#       'indices': [268, 291],
#       'media_url': 'http://pbs.twimg.com/media/DiznDecVsAAJuFd.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DiznDecVsAAJuFd.jpg',
#       'url': 'https://t.co/b3IWtfhSQo',
#       'display_url': 'pic.twitter.com/b3IWtfhSQo',
#       'expanded_url': 'https://twitter.com/CNUSD/status/1021445383233286145/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1583, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 927, 'h': 1200, 'resize': 'fit'}}},
#      {'id': 1021445333807607809,
#       'id_str': '1021445333807607809',
#       'indices': [268, 291],
#       'media_url': 'http://pbs.twimg.com/media/DiznHocVMAE1Yr3.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DiznHocVMAE1Yr3.jpg',
#       'url': 'https://t.co/b3IWtfhSQo',
#       'display_url': 'pic.twitter.com/b3IWtfhSQo',
#       'expanded_url': 'https://twitter.com/CNUSD/status/1021445383233286145/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 927, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1583, 'h': 2048, 'resize': 'fit'}}},
#      {'id': 1021445337788006400,
#       'id_str': '1021445337788006400',
#       'indices': [268, 291],
#       'media_url': 'http://pbs.twimg.com/media/DiznH3RVQAAwmIX.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DiznH3RVQAAwmIX.jpg',
#       'url': 'https://t.co/b3IWtfhSQo',
#       'display_url': 'pic.twitter.com/b3IWtfhSQo',
#       'expanded_url': 'https://twitter.com/CNUSD/status/1021445383233286145/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1583, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 927, 'h': 1200, 'resize': 'fit'}}},
#      {'id': 1021445334675873792,
#       'id_str': '1021445334675873792',
#       'indices': [268, 291],
#       'media_url': 'http://pbs.twimg.com/media/DiznHrrV4AAyYhf.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DiznHrrV4AAyYhf.jpg',
#       'url': 'https://t.co/b3IWtfhSQo',
#       'display_url': 'pic.twitter.com/b3IWtfhSQo',
#       'expanded_url': 'https://twitter.com/CNUSD/status/1021445383233286145/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 927, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1583, 'h': 2048, 'resize': 'fit'}}}]}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/VCIPqfmq3Z',
#      'expanded_url': 'https://twitter.com/i/web/status/1021445383233286145',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [121, 144]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en'},
#  'quoted_status_permalink': {'url': 'https://t.co/TaZojlath4',
#   'expanded': 'https://twitter.com/cnusd/status/1021445383233286145',
#   'display': 'twitter.com/cnusd/status/1…'},
#  'is_quote_status': True,
#  'extended_tweet': {'full_text': 'We also have some amazing student speakers and performers from that will be showcased at the Equity in Education conference next week! There’s still time to register!! @CNUSD #CNUSDEquity18 #CNUSDfutureready @ERHSOfficial @jeremyegoins https://t.co/TaZojlath4',
#   'display_text_range': [0, 235],
#   'entities': {'hashtags': [{'text': 'CNUSDEquity18', 'indices': [175, 189]},
#     {'text': 'CNUSDfutureready', 'indices': [190, 207]}],
#    'urls': [{'url': 'https://t.co/TaZojlath4',
#      'expanded_url': 'https://twitter.com/cnusd/status/1021445383233286145',
#      'display_url': 'twitter.com/cnusd/status/1…',
#      'indices': [236, 259]}],
#    'user_mentions': [{'screen_name': 'CNUSD',
#      'name': 'Corona-Norco USD',
#      'id': 64570444,
#      'id_str': '64570444',
#      'indices': [168, 174]},
#     {'screen_name': 'ERHSOfficial',
#      'name': 'Eleanor Roosevelt HS',
#      'id': 3343340534,
#      'id_str': '3343340534',
#      'indices': [208, 221]},
#     {'screen_name': 'jeremyegoins',
#      'name': 'Jeremy Goins, Ed.D',
#      'id': 273033877,
#      'id_str': '273033877',
#      'indices': [222, 235]}],
#    'symbols': []}},
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [{'url': 'https://t.co/Srn7WifY90',
#     'expanded_url': 'https://twitter.com/i/web/status/1021557636376883200',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}],
#   'user_mentions': [],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'filter_level': 'low',
#  'lang': 'en',
#  'timestamp_ms': '1532393294792'}

# %% [markdown]
# What is the type of `this_tweet`?

# %%
this_tweet=next(tweet_iterator)

# %% [markdown]
# Display the keys of `this_tweet`.

# %%
type(this_tweet)
# Out:
# twitter.api.TwitterDictResponse

# %%
import pandas as pd
df= pd.DataFrame(this_tweet)
df.keys()
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'quote_count', 'reply_count',
#        'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted',
#        'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %% [markdown]
# Display the `text` and `user` of `this_tweet`.

# %%
dictionary=this_tweet
dictionary.get('text')
dictionary.get('user')
# Out:
# {'id': 129051973,
#  'id_str': '129051973',
#  'name': 'Leli',
#  'screen_name': 'aarelifigueroaa',
#  'location': None,
#  'url': None,
#  'description': 'they call me la güerita 🇲🇽 y me encanta bailar 💃🏽',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 327,
#  'friends_count': 190,
#  'listed_count': 1,
#  'favourites_count': 5513,
#  'statuses_count': 4248,
#  'created_at': 'Sat Apr 03 01:36:39 +0000 2010',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'lang': 'en',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_link_color': 'F5B800',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1021286452196331520/WkypF3l6_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021286452196331520/WkypF3l6_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/129051973/1531330760',
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None}

# %% [markdown]
# ## Collect Tweets
#
# Create an empty list called `tweets`.
#
# Use a `for`-loop to collect ten tweets and add them to this list.

# %%
tweets=[]
for _ in range(10):
    this_tweet=next(tweet_iterator)
    tweets.append(this_tweet)
tweets
# Out:
# [{'created_at': 'Tue Jul 24 00:49:04 +0000 2018',
#   'id': 1021557846016589825,
#   'id_str': '1021557846016589825',
#   'text': '@AmberLeeNews Have fun!!! And by the way I am coconuts over you...',
#   'display_text_range': [14, 66],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1021399566162284545,
#   'in_reply_to_status_id_str': '1021399566162284545',
#   'in_reply_to_user_id': 15686484,
#   'in_reply_to_user_id_str': '15686484',
#   'in_reply_to_screen_name': 'AmberLeeNews',
#   'user': {'id': 1273233847,
#    'id_str': '1273233847',
#    'name': 'Robert Bruns',
#    'screen_name': 'bbrunsjr',
#    'location': None,
#    'url': None,
#    'description': None,
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 15,
#    'friends_count': 285,
#    'listed_count': 0,
#    'favourites_count': 4095,
#    'statuses_count': 227,
#    'created_at': 'Sat Mar 16 20:24:14 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '02215ae29a77567c',
#    'url': 'https://api.twitter.com/1.1/geo/id/02215ae29a77567c.json',
#    'place_type': 'city',
#    'name': 'Tustin',
#    'full_name': 'Tustin, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-117.845301, 33.69418],
#       [-117.845301, 33.773387],
#       [-117.758969, 33.773387],
#       [-117.758969, 33.69418]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'AmberLeeNews',
#      'name': 'Amber Lee',
#      'id': 15686484,
#      'id_str': '15686484',
#      'indices': [0, 13]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532393344774'},
#  {'created_at': 'Tue Jul 24 00:49:08 +0000 2018',
#   'id': 1021557862403780608,
#   'id_str': '1021557862403780608',
#   'text': '@auntie_jackiee 😂 that’s really my fave meme now',
#   'display_text_range': [16, 48],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1021555451761250306,
#   'in_reply_to_status_id_str': '1021555451761250306',
#   'in_reply_to_user_id': 317586946,
#   'in_reply_to_user_id_str': '317586946',
#   'in_reply_to_screen_name': 'auntie_jackiee',
#   'user': {'id': 1665726248,
#    'id_str': '1665726248',
#    'name': 'Simone 🌺',
#    'screen_name': 'MonieMeetsWorld',
#    'location': 'San Junipero, Los Angeles, CA',
#    'url': 'http://www.thegoodnewsradiostation.com',
#    'description': 'writer, marketeer, top ramen enthusiast, part time hippy, and pop culture junkie',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 366,
#    'friends_count': 338,
#    'listed_count': 20,
#    'favourites_count': 2988,
#    'statuses_count': 14426,
#    'created_at': 'Mon Aug 12 18:25:06 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_link_color': 'F58EA8',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1012185873876541441/6IxuRort_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1012185873876541441/6IxuRort_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1665726248/1469431570',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'auntie_jackiee',
#      'name': 'Simone🌻',
#      'id': 317586946,
#      'id_str': '317586946',
#      'indices': [0, 15]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532393348681'},
#  {'created_at': 'Tue Jul 24 00:49:11 +0000 2018',
#   'id': 1021557875053715457,
#   'id_str': '1021557875053715457',
#   'text': 'Bubbles is cool  https://t.co/gfXl6m69Lm',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1540942170,
#    'id_str': '1540942170',
#    'name': '#reputationStadiumTour',
#    'screen_name': 'repuTaylorERA',
#    'location': 'Sunny California',
#    'url': None,
#    'description': 'i ❤️👑TAYLOR SWIFT!❤️ Olivia &Mere,REPUTATION ALBUM🐍,REPTOURPASADENA,TEAM LIQUID ESPORT TEAM,TOMBRADY, NEW ENGLAND PATRIOTS 🏈GilletteStadium my ❤️',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 2683,
#    'friends_count': 2451,
#    'listed_count': 89,
#    'favourites_count': 36985,
#    'statuses_count': 102071,
#    'created_at': 'Sun Jun 23 13:20:05 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1020678544001675264/dOfWoLJw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1020678544001675264/dOfWoLJw_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1540942170/1528868887',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [],
#    'symbols': [],
#    'media': [{'id': 872475877879275522,
#      'id_str': '872475877879275522',
#      'indices': [17, 40],
#      'additional_media_info': {'monetizable': False},
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/872475877879275522/pu/img/W53Je9MwdzAvsoZP.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/872475877879275522/pu/img/W53Je9MwdzAvsoZP.jpg',
#      'url': 'https://t.co/gfXl6m69Lm',
#      'display_url': 'pic.twitter.com/gfXl6m69Lm',
#      'expanded_url': 'https://twitter.com/virtuallydead/status/872476247384887296/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 200, 'h': 360, 'resize': 'fit'},
#       'small': {'w': 200, 'h': 360, 'resize': 'fit'},
#       'large': {'w': 200, 'h': 360, 'resize': 'fit'}},
#      'source_status_id': 872476247384887296,
#      'source_status_id_str': '872476247384887296',
#      'source_user_id': 20538843,
#      'source_user_id_str': '20538843'}]},
#   'extended_entities': {'media': [{'id': 872475877879275522,
#      'id_str': '872475877879275522',
#      'indices': [17, 40],
#      'additional_media_info': {'monetizable': False},
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/872475877879275522/pu/img/W53Je9MwdzAvsoZP.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/872475877879275522/pu/img/W53Je9MwdzAvsoZP.jpg',
#      'url': 'https://t.co/gfXl6m69Lm',
#      'display_url': 'pic.twitter.com/gfXl6m69Lm',
#      'expanded_url': 'https://twitter.com/virtuallydead/status/872476247384887296/video/1',
#      'type': 'video',
#      'video_info': {'aspect_ratio': [5, 9],
#       'duration_millis': 25567,
#       'variants': [{'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/872475877879275522/pu/vid/176x320/uurATFz2dcCmCEvw.mp4'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/872475877879275522/pu/pl/zVxpNhq0-UCDD-de.m3u8'}]},
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 200, 'h': 360, 'resize': 'fit'},
#       'small': {'w': 200, 'h': 360, 'resize': 'fit'},
#       'large': {'w': 200, 'h': 360, 'resize': 'fit'}},
#      'source_status_id': 872476247384887296,
#      'source_status_id_str': '872476247384887296',
#      'source_user_id': 20538843,
#      'source_user_id_str': '20538843'}]},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532393351697'},
#  {'created_at': 'Tue Jul 24 00:49:22 +0000 2018',
#   'id': 1021557918435487744,
#   'id_str': '1021557918435487744',
#   'text': 'During @BadKlaat when my whole squad got the fuck down love these edm fucks 💕💕 https://t.co/TU595XsVr8',
#   'display_text_range': [0, 78],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1021517844406624256,
#   'in_reply_to_status_id_str': '1021517844406624256',
#   'in_reply_to_user_id': 2686275378,
#   'in_reply_to_user_id_str': '2686275378',
#   'in_reply_to_screen_name': 'anamoraless_',
#   'user': {'id': 2686275378,
#    'id_str': '2686275378',
#    'name': 'ana (✿◠‿◠)',
#    'screen_name': 'anamoraless_',
#    'location': 'Fresno, CA',
#    'url': 'https://www.instagram.com/_anamoraless/?hl=en',
#    'description': '@stevenbrunomars 💘 • 22  • #D0GH0U53🐶 #Wonderers💜 #🅱️arongFamily👹',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1025,
#    'friends_count': 579,
#    'listed_count': 6,
#    'favourites_count': 16056,
#    'statuses_count': 24670,
#    'created_at': 'Mon Jul 28 01:06:16 +0000 2014',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': 'F58EA8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1018565409430073344/1X8ylrLr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1018565409430073344/1X8ylrLr_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2686275378/1530138861',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'BadKlaat',
#      'name': 'BadKlaat',
#      'id': 145600432,
#      'id_str': '145600432',
#      'indices': [7, 16]}],
#    'symbols': [],
#    'media': [{'id': 1021557711220035584,
#      'id_str': '1021557711220035584',
#      'indices': [79, 102],
#      'additional_media_info': {'monetizable': False},
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1021557711220035584/pu/img/DK0gAc_IPBlbRoHS.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1021557711220035584/pu/img/DK0gAc_IPBlbRoHS.jpg',
#      'url': 'https://t.co/TU595XsVr8',
#      'display_url': 'pic.twitter.com/TU595XsVr8',
#      'expanded_url': 'https://twitter.com/anamoraless_/status/1021557918435487744/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 382, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 404, 'h': 720, 'resize': 'fit'},
#       'large': {'w': 404, 'h': 720, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1021557711220035584,
#      'id_str': '1021557711220035584',
#      'indices': [79, 102],
#      'additional_media_info': {'monetizable': False},
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1021557711220035584/pu/img/DK0gAc_IPBlbRoHS.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1021557711220035584/pu/img/DK0gAc_IPBlbRoHS.jpg',
#      'url': 'https://t.co/TU595XsVr8',
#      'display_url': 'pic.twitter.com/TU595XsVr8',
#      'expanded_url': 'https://twitter.com/anamoraless_/status/1021557918435487744/video/1',
#      'type': 'video',
#      'video_info': {'aspect_ratio': [101, 180],
#       'duration_millis': 16185,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1021557711220035584/pu/pl/OlJTRH6aZNMWdrwY.m3u8?tag=3'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1021557711220035584/pu/vid/358x640/PIg3xaDsbYG_LeL3.mp4?tag=3'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1021557711220035584/pu/vid/178x320/jzB9cl_Rbpvr9gxB.mp4?tag=3'}]},
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 382, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 404, 'h': 720, 'resize': 'fit'},
#       'large': {'w': 404, 'h': 720, 'resize': 'fit'}}}]},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532393362040'},
#  {'created_at': 'Tue Jul 24 00:49:23 +0000 2018',
#   'id': 1021557922835324929,
#   'id_str': '1021557922835324929',
#   'text': '@KimDotcom @JudicialWatch Yes!  @JudicialWatch @TomFitton I’ll donate to the cause.',
#   'display_text_range': [26, 83],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1021554537255993344,
#   'in_reply_to_status_id_str': '1021554537255993344',
#   'in_reply_to_user_id': 611986351,
#   'in_reply_to_user_id_str': '611986351',
#   'in_reply_to_screen_name': 'KimDotcom',
#   'user': {'id': 810217393792237568,
#    'id_str': '810217393792237568',
#    'name': 'Mr. Wayne',
#    'screen_name': 'gregirvine78',
#    'location': 'California, USA',
#    'url': None,
#    'description': 'Fiscally conservative. Socially liberal. Proud supporter of all first responders and our military.  Proud American. Ashamed of our current political climate.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 158,
#    'friends_count': 335,
#    'listed_count': 0,
#    'favourites_count': 18079,
#    'statuses_count': 4857,
#    'created_at': 'Sat Dec 17 20:17:34 +0000 2016',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021555956381962240/f4wU-9T-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021555956381962240/f4wU-9T-_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/810217393792237568/1523886467',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'KimDotcom',
#      'name': 'Kim Dotcom',
#      'id': 611986351,
#      'id_str': '611986351',
#      'indices': [0, 10]},
#     {'screen_name': 'JudicialWatch',
#      'name': 'Judicial Watch 🔎',
#      'id': 18247062,
#      'id_str': '18247062',
#      'indices': [11, 25]},
#     {'screen_name': 'JudicialWatch',
#      'name': 'Judicial Watch 🔎',
#      'id': 18247062,
#      'id_str': '18247062',
#      'indices': [32, 46]},
#     {'screen_name': 'TomFitton',
#      'name': 'Tom Fitton',
#      'id': 18266688,
#      'id_str': '18266688',
#      'indices': [47, 57]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532393363089'},
#  {'created_at': 'Tue Jul 24 00:49:23 +0000 2018',
#   'id': 1021557924068556800,
#   'id_str': '1021557924068556800',
#   'text': "I'm at San Francisco International Airport Yoga Room in South San Francisco, Calif https://t.co/AWrFr7TNjL",
#   'source': '<a href="http://foursquare.com" rel="nofollow">Foursquare</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15595248,
#    'id_str': '15595248',
#    'name': 'Rolo Rolo',
#    'screen_name': 'rolodj',
#    'location': 'San Francisco, CA',
#    'url': 'http://about.me/rolotalorda',
#    'description': 'I drink, therefore I am... drunk',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 383,
#    'friends_count': 815,
#    'listed_count': 55,
#    'favourites_count': 458,
#    'statuses_count': 24226,
#    'created_at': 'Fri Jul 25 06:52:03 +0000 2008',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'BADFCD',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'CCFF00',
#    'profile_text_color': '0C3E53',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/953857939936178177/I2KwF3H8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/953857939936178177/I2KwF3H8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15595248/1364963513',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': {'type': 'Point', 'coordinates': [37.62123917, -122.37573045]},
#   'coordinates': {'type': 'Point',
#    'coordinates': [-122.37573045, 37.62123917]},
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/AWrFr7TNjL',
#      'expanded_url': 'https://www.swarmapp.com/c/8OshDO9Wmhw',
#      'display_url': 'swarmapp.com/c/8OshDO9Wmhw',
#      'indices': [83, 106]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532393363383'},
#  {'created_at': 'Tue Jul 24 00:49:25 +0000 2018',
#   'id': 1021557931001573376,
#   'id_str': '1021557931001573376',
#   'text': 'So glad you and your nieces are enjoying the show! https://t.co/PAnQ9ZUHuJ',
#   'display_text_range': [0, 50],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 11696042,
#    'id_str': '11696042',
#    'name': 'Aliki Theofilopoulos',
#    'screen_name': 'alikigreeky',
#    'location': 'Los Angeles',
#    'url': 'http://www.alikigreeky.com',
#    'description': 'DreamWorks SP on Harvey Street Kids.Disney EP/Director of Descendants Wicked World. Worked on Phineas & Ferb and Mickey.Napkin Doodler,Mom,Greek,gave a TED Talk',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 5652,
#    'friends_count': 1361,
#    'listed_count': 155,
#    'favourites_count': 21878,
#    'statuses_count': 17529,
#    'created_at': 'Mon Dec 31 18:49:21 +0000 2007',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'ACDED6',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': '038543',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F6F6F6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/644777276035301376/xCJRQwh7_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/644777276035301376/xCJRQwh7_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/11696042/1527890200',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'quoted_status_id': 1021513001952862208,
#   'quoted_status_id_str': '1021513001952862208',
#   'quoted_status': {'created_at': 'Mon Jul 23 21:50:53 +0000 2018',
#    'id': 1021513001952862208,
#    'id_str': '1021513001952862208',
#    'text': 'My nieces are visiting me and I put #HarveyStreetKids on as a whim. We’re now all hooked!! Very sweet, charming sho… https://t.co/2juVDoUFzY',
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2293636578,
#     'id_str': '2293636578',
#     'name': 'meg',
#     'screen_name': 'megohhoney',
#     'location': 'Maine, USA',
#     'url': None,
#     'description': 'I’m growing and becoming the beautiful young woman god intended me to be',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 33,
#     'friends_count': 114,
#     'listed_count': 0,
#     'favourites_count': 3285,
#     'statuses_count': 550,
#     'created_at': 'Thu Jan 16 01:23:30 +0000 2014',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/994710063389528064/tvA13WhN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/994710063389528064/tvA13WhN_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2293636578/1495309926',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'My nieces are visiting me and I put #HarveyStreetKids on as a whim. We’re now all hooked!! Very sweet, charming show that everyone can enjoy.',
#     'display_text_range': [0, 141],
#     'entities': {'hashtags': [{'text': 'HarveyStreetKids',
#        'indices': [36, 53]}],
#      'urls': [],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'entities': {'hashtags': [{'text': 'HarveyStreetKids',
#       'indices': [36, 53]}],
#     'urls': [{'url': 'https://t.co/2juVDoUFzY',
#       'expanded_url': 'https://twitter.com/i/web/status/1021513001952862208',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'quoted_status_permalink': {'url': 'https://t.co/PAnQ9ZUHuJ',
#    'expanded': 'https://twitter.com/megohhoney/status/1021513001952862208',
#    'display': 'twitter.com/megohhoney/sta…'},
#   'is_quote_status': True,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/PAnQ9ZUHuJ',
#      'expanded_url': 'https://twitter.com/megohhoney/status/1021513001952862208',
#      'display_url': 'twitter.com/megohhoney/sta…',
#      'indices': [51, 74]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532393365036'},
#  {'created_at': 'Tue Jul 24 00:49:25 +0000 2018',
#   'id': 1021557932138356736,
#   'id_str': '1021557932138356736',
#   'text': 'taylordevlinn is fricken stunning \U0001f929\n#ochairstylist #oc #orangecounty #ocstylist #newportbeach #costamesa… https://t.co/PzyYOInZlI',
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 802002518,
#    'id_str': '802002518',
#    'name': 'Olivia Tacalo',
#    'screen_name': 'OliviaTacalo',
#    'location': 'Irvine, CA',
#    'url': None,
#    'description': 'Hell on heels ⚓',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 37,
#    'friends_count': 53,
#    'listed_count': 0,
#    'favourites_count': 9,
#    'statuses_count': 116,
#    'created_at': 'Tue Sep 04 07:48:44 +0000 2012',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/735293833047465986/uW4Hx4mk_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/735293833047465986/uW4Hx4mk_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/802002518/1370368015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': {'type': 'Point', 'coordinates': [33.6402166, -117.92020454]},
#   'coordinates': {'type': 'Point', 'coordinates': [-117.92020454, 33.6402166]},
#   'place': {'id': '2f97b9acb13ca665',
#    'url': 'https://api.twitter.com/1.1/geo/id/2f97b9acb13ca665.json',
#    'place_type': 'city',
#    'name': 'Costa Mesa',
#    'full_name': 'Costa Mesa, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-117.954201, 33.625179],
#       [-117.954201, 33.702038],
#       [-117.85709, 33.702038],
#       [-117.85709, 33.625179]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': 'taylordevlinn is fricken stunning \U0001f929\n#ochairstylist #oc #orangecounty #ocstylist #newportbeach #costamesa #solasalons #redkenshadeseq #americansalon #modernsalon… https://t.co/JDIfz4A1Ao',
#    'display_text_range': [0, 185],
#    'entities': {'hashtags': [{'text': 'ochairstylist', 'indices': [36, 50]},
#      {'text': 'oc', 'indices': [51, 54]},
#      {'text': 'orangecounty', 'indices': [55, 68]},
#      {'text': 'ocstylist', 'indices': [69, 79]},
#      {'text': 'newportbeach', 'indices': [80, 93]},
#      {'text': 'costamesa', 'indices': [94, 104]},
#      {'text': 'solasalons', 'indices': [105, 116]},
#      {'text': 'redkenshadeseq', 'indices': [117, 132]},
#      {'text': 'americansalon', 'indices': [133, 147]},
#      {'text': 'modernsalon', 'indices': [148, 160]}],
#     'urls': [{'url': 'https://t.co/JDIfz4A1Ao',
#       'expanded_url': 'https://www.instagram.com/p/BlmEnWxg8Xg/?utm_source=ig_twitter_share&igshid=1f52lt9o3yzli',
#       'display_url': 'instagram.com/p/BlmEnWxg8Xg/…',
#       'indices': [162, 185]}],
#     'user_mentions': [],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'ochairstylist', 'indices': [36, 50]},
#     {'text': 'oc', 'indices': [51, 54]},
#     {'text': 'orangecounty', 'indices': [55, 68]},
#     {'text': 'ocstylist', 'indices': [69, 79]},
#     {'text': 'newportbeach', 'indices': [80, 93]},
#     {'text': 'costamesa', 'indices': [94, 104]}],
#    'urls': [{'url': 'https://t.co/PzyYOInZlI',
#      'expanded_url': 'https://twitter.com/i/web/status/1021557932138356736',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [106, 129]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'sv',
#   'timestamp_ms': '1532393365307'},
#  {'created_at': 'Tue Jul 24 00:49:25 +0000 2018',
#   'id': 1021557932209528833,
#   'id_str': '1021557932209528833',
#   'text': '✈️ En route to ☁️ #cloudnext18 Partner Summit! Can’t wait to share with you guys all we learn! #multivalue https://t.co/xp5xyVbBL7',
#   'display_text_range': [0, 106],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 174385871,
#    'id_str': '174385871',
#    'name': 'Mark Pick☁️',
#    'screen_name': 'CdMPick',
#    'location': 'Newport Beach, CA',
#    'url': 'http://mypickcloud.com',
#    'description': 'Husband, Father, sports fan, Pick/MultiValue evangelist marketing the Pick #MultiValue database in the #GoogleCloud, but the opinions I express here are my own.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 341,
#    'friends_count': 518,
#    'listed_count': 9,
#    'favourites_count': 1550,
#    'statuses_count': 443,
#    'created_at': 'Tue Aug 03 20:16:57 +0000 2010',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '5FAFE1',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/894775005522702337/n3gjwc9r_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/894775005522702337/n3gjwc9r_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/174385871/1442417800',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '07d9c92b30487003',
#    'url': 'https://api.twitter.com/1.1/geo/id/07d9c92b30487003.json',
#    'place_type': 'poi',
#    'name': 'John Wayne Airport (SNA)',
#    'full_name': 'John Wayne Airport (SNA)',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-117.86768, 33.673997],
#       [-117.86768, 33.673997],
#       [-117.86768, 33.673997],
#       [-117.86768, 33.673997]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'cloudnext18', 'indices': [18, 30]},
#     {'text': 'multivalue', 'indices': [95, 106]}],
#    'urls': [],
#    'user_mentions': [],
#    'symbols': [],
#    'media': [{'id': 1021557841188933632,
#      'id_str': '1021557841188933632',
#      'indices': [107, 130],
#      'additional_media_info': {'monetizable': False},
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1021557841188933632/pu/img/Ct80XSROOIxBcxRR.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1021557841188933632/pu/img/Ct80XSROOIxBcxRR.jpg',
#      'url': 'https://t.co/xp5xyVbBL7',
#      'display_url': 'pic.twitter.com/xp5xyVbBL7',
#      'expanded_url': 'https://twitter.com/CdMPick/status/1021557932209528833/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1021557841188933632,
#      'id_str': '1021557841188933632',
#      'indices': [107, 130],
#      'additional_media_info': {'monetizable': False},
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1021557841188933632/pu/img/Ct80XSROOIxBcxRR.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1021557841188933632/pu/img/Ct80XSROOIxBcxRR.jpg',
#      'url': 'https://t.co/xp5xyVbBL7',
#      'display_url': 'pic.twitter.com/xp5xyVbBL7',
#      'expanded_url': 'https://twitter.com/CdMPick/status/1021557932209528833/video/1',
#      'type': 'video',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 33300,
#       'variants': [{'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1021557841188933632/pu/vid/640x360/T8Zevt-nGtU-3Nz4.mp4?tag=3'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1021557841188933632/pu/vid/320x180/EOTlQOTh3ybjtBze.mp4?tag=3'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1021557841188933632/pu/pl/TwrieU49XV1kHYj4.m3u8?tag=3'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1021557841188933632/pu/vid/1280x720/JFI0QUZybwB4wEL4.mp4?tag=3'}]},
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532393365324'},
#  {'created_at': 'Tue Jul 24 00:49:26 +0000 2018',
#   'id': 1021557939021197312,
#   'id_str': '1021557939021197312',
#   'text': '#funtime en los aparadores de #footlocker en @shopglendale #comingsoon #kidsshoes  \U0001f92a😂🤣 #mienanofavorito… https://t.co/iDRS0y26lC',
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1925233916,
#    'id_str': '1925233916',
#    'name': 'Fabian Serrano',
#    'screen_name': 'fabsserrano',
#    'location': 'Los Angeles, CA',
#    'url': 'http://www.radionotas.com',
#    'description': 'Radio Producer Morning Show\n979 La Raza SBS Los Angeles\nRadioNotas',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 196,
#    'friends_count': 84,
#    'listed_count': 5,
#    'favourites_count': 69,
#    'statuses_count': 1745,
#    'created_at': 'Wed Oct 02 01:28:00 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'es',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'B2DFDA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '93A644',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/692070295721496576/RCAFK_9t_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/692070295721496576/RCAFK_9t_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1925233916/1454020319',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': {'type': 'Point', 'coordinates': [34.1455979, -118.2578027]},
#   'coordinates': {'type': 'Point', 'coordinates': [-118.2578027, 34.1455979]},
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'Estados Unidos',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': '#funtime en los aparadores de #footlocker en @shopglendale #comingsoon #kidsshoes  \U0001f92a😂🤣 #mienanofavorito #sebastianstan #mylove 🤘 en Glendale Galleria https://t.co/GAo1Ai0SCi',
#    'display_text_range': [0, 173],
#    'entities': {'hashtags': [{'text': 'funtime', 'indices': [0, 8]},
#      {'text': 'footlocker', 'indices': [30, 41]},
#      {'text': 'comingsoon', 'indices': [59, 70]},
#      {'text': 'kidsshoes', 'indices': [71, 81]},
#      {'text': 'mienanofavorito', 'indices': [87, 103]},
#      {'text': 'sebastianstan', 'indices': [104, 118]},
#      {'text': 'mylove', 'indices': [119, 126]}],
#     'urls': [{'url': 'https://t.co/GAo1Ai0SCi',
#       'expanded_url': 'https://www.instagram.com/p/BlmEnjxAdSw/?utm_source=ig_twitter_share&igshid=12b1xysu91c41',
#       'display_url': 'instagram.com/p/BlmEnjxAdSw/…',
#       'indices': [150, 173]}],
#     'user_mentions': [{'screen_name': 'ShopGlendale',
#       'name': 'Glendale Galleria',
#       'id': 82702191,
#       'id_str': '82702191',
#       'indices': [45, 58]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'funtime', 'indices': [0, 8]},
#     {'text': 'footlocker', 'indices': [30, 41]},
#     {'text': 'comingsoon', 'indices': [59, 70]},
#     {'text': 'kidsshoes', 'indices': [71, 81]},
#     {'text': 'mienanofavorito', 'indices': [87, 103]}],
#    'urls': [{'url': 'https://t.co/iDRS0y26lC',
#      'expanded_url': 'https://twitter.com/i/web/status/1021557939021197312',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [105, 128]}],
#    'user_mentions': [{'screen_name': 'ShopGlendale',
#      'name': 'Glendale Galleria',
#      'id': 82702191,
#      'id_str': '82702191',
#      'indices': [45, 58]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'es',
#   'timestamp_ms': '1532393366948'}]

# %% [markdown]
# Display `tweets` in a DataFrame.

# %%
df_10 = pd.DataFrame(tweets)
df_10
# Out:
#   contributors                                        coordinates  \
# 0         None                                               None
# 1         None                                               None
# 2         None                                               None
# 3         None                                               None
# 4         None                                               None
# 5         None  {'type': 'Point', 'coordinates': [-122.3757304...
# 6         None                                               None
# 7         None  {'type': 'Point', 'coordinates': [-117.9202045...
# 8         None                                               None
# 9         None  {'type': 'Point', 'coordinates': [-118.2578027...
#
#                        created_at display_text_range  \
# 0  Tue Jul 24 00:49:04 +0000 2018           [14, 66]
# 1  Tue Jul 24 00:49:08 +0000 2018           [16, 48]
# 2  Tue Jul 24 00:49:11 +0000 2018                NaN
# 3  Tue Jul 24 00:49:22 +0000 2018            [0, 78]
# 4  Tue Jul 24 00:49:23 +0000 2018           [26, 83]
# 5  Tue Jul 24 00:49:23 +0000 2018                NaN
# 6  Tue Jul 24 00:49:25 +0000 2018            [0, 50]
# 7  Tue Jul 24 00:49:25 +0000 2018                NaN
# 8  Tue Jul 24 00:49:25 +0000 2018           [0, 106]
# 9  Tue Jul 24 00:49:26 +0000 2018                NaN
#
#                                             entities  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 5  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 6  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 7  {'hashtags': [{'text': 'ochairstylist', 'indic...
# 8  {'hashtags': [{'text': 'cloudnext18', 'indices...
# 9  {'hashtags': [{'text': 'funtime', 'indices': [...
#
#                                    extended_entities  \
# 0                                                NaN
# 1                                                NaN
# 2  {'media': [{'id': 872475877879275522, 'id_str'...
# 3  {'media': [{'id': 1021557711220035584, 'id_str...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  {'media': [{'id': 1021557841188933632, 'id_str...
# 9                                                NaN
#
#                                       extended_tweet  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2                                                NaN               0
# 3                                                NaN               0
# 4                                                NaN               0
# 5                                                NaN               0
# 6                                                NaN               0
# 7  {'full_text': 'taylordevlinn is fricken stunni...               0
# 8                                                NaN               0
# 9  {'full_text': '#funtime en los aparadores de #...               0
#
#    favorited filter_level                        ...                          \
# 0      False          low                        ...
# 1      False          low                        ...
# 2      False          low                        ...
# 3      False          low                        ...
# 4      False          low                        ...
# 5      False          low                        ...
# 6      False          low                        ...
# 7      False          low                        ...
# 8      False          low                        ...
# 9      False          low                        ...
#
#   quoted_status_id_str                            quoted_status_permalink  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# 5                  NaN                                                NaN
# 6  1021513001952862208  {'url': 'https://t.co/PAnQ9ZUHuJ', 'expanded':...
# 7                  NaN                                                NaN
# 8                  NaN                                                NaN
# 9                  NaN                                                NaN
#
#   reply_count retweet_count  retweeted  \
# 0           0             0      False
# 1           0             0      False
# 2           0             0      False
# 3           0             0      False
# 4           0             0      False
# 5           0             0      False
# 6           0             0      False
# 7           0             0      False
# 8           0             0      False
# 9           0             0      False
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://foursquare.com" rel="nofollow"...
# 6  <a href="http://twitter.com/download/iphone" r...
# 7  <a href="http://instagram.com" rel="nofollow">...
# 8  <a href="http://twitter.com/download/iphone" r...
# 9  <a href="http://instagram.com" rel="nofollow">...
#
#                                                 text   timestamp_ms  \
# 0  @AmberLeeNews Have fun!!! And by the way I am ...  1532393344774
# 1   @auntie_jackiee 😂 that’s really my fave meme now  1532393348681
# 2           Bubbles is cool  https://t.co/gfXl6m69Lm  1532393351697
# 3  During @BadKlaat when my whole squad got the f...  1532393362040
# 4  @KimDotcom @JudicialWatch Yes!  @JudicialWatch...  1532393363089
# 5  I'm at San Francisco International Airport Yog...  1532393363383
# 6  So glad you and your nieces are enjoying the s...  1532393365036
# 7  taylordevlinn is fricken stunning 🤩\n#ochairst...  1532393365307
# 8  ✈️ En route to ☁️ #cloudnext18 Partner Summit!...  1532393365324
# 9  #funtime en los aparadores de #footlocker en @...  1532393366948
#
#    truncated                                               user
# 0      False  {'id': 1273233847, 'id_str': '1273233847', 'na...
# 1      False  {'id': 1665726248, 'id_str': '1665726248', 'na...
# 2      False  {'id': 1540942170, 'id_str': '1540942170', 'na...
# 3      False  {'id': 2686275378, 'id_str': '2686275378', 'na...
# 4      False  {'id': 810217393792237568, 'id_str': '81021739...
# 5      False  {'id': 15595248, 'id_str': '15595248', 'name':...
# 6      False  {'id': 11696042, 'id_str': '11696042', 'name':...
# 7       True  {'id': 802002518, 'id_str': '802002518', 'name...
# 8      False  {'id': 174385871, 'id_str': '174385871', 'name...
# 9       True  {'id': 1925233916, 'id_str': '1925233916', 'na...
#
# [10 rows x 35 columns]

# %% [markdown]
# Display just the test of the tweets using DataFrame.

# %%
df_10.text
# Out:
# 0    @AmberLeeNews Have fun!!! And by the way I am ...
# 1     @auntie_jackiee 😂 that’s really my fave meme now
# 2             Bubbles is cool  https://t.co/gfXl6m69Lm
# 3    During @BadKlaat when my whole squad got the f...
# 4    @KimDotcom @JudicialWatch Yes!  @JudicialWatch...
# 5    I'm at San Francisco International Airport Yog...
# 6    So glad you and your nieces are enjoying the s...
# 7    taylordevlinn is fricken stunning 🤩\n#ochairst...
# 8    ✈️ En route to ☁️ #cloudnext18 Partner Summit!...
# 9    #funtime en los aparadores de #footlocker en @...
# Name: text, dtype: object

# %% [markdown]
# What is the type of `tweets`?

# %%
type(df_10)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Write a list comprehension to display the type of each of the objects in `tweets`.

# %%
list =[]
for column in df_10:
    list.append(type(column))
list
# Out:
# [str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str]

# %% [markdown]
# Import the `json` library.

# %%
import json

# %% [markdown]
# Create an object called `tweets_string` using `json.dumps()`.
#
# Display the first 500 characters of this string.

# %%
tweet_string=json.dumps(tweets)[:500]
tweet_string
# Out:
# '[{"created_at": "Tue Jul 24 00:49:04 +0000 2018", "id": 1021557846016589825, "id_str": "1021557846016589825", "text": "@AmberLeeNews Have fun!!! And by the way I am coconuts over you...", "display_text_range": [14, 66], "source": "<a href=\\"http://twitter.com/download/iphone\\" rel=\\"nofollow\\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": 1021399566162284545, "in_reply_to_status_id_str": "1021399566162284545", "in_reply_to_user_id": 15686484, "in_reply_to_user_id_str": "1'

# %% [markdown]
# ## Write Tweets to Disk
#
# Using this pattern
#
#     with open(filename_as_string, 'w') as outfile:
#         json.dump(python_object, outfile)
#
# write `tweets` to disk as json.

# %%
from lib import create_timestamped_filename
username='jia'
filename = create_timestamped_filename(username)
with open(filename, 'w') as outfile:     
    json.dump(tweets, outfile)

# %% [markdown]
# ## Read Tweets from Disk
#
# Using this pattern
#
#     with open(filename_as_string) as infile:
#         json_data=infile.read()
#         python_object_from_disk = json.loads(json_data)
#
# read the tweets from the json. Store them as `tweets_from_disk`.

# %% [markdown]
# Display `tweets_from_disk` as a DataFrame.
